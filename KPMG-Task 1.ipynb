# %% [markdown]
# # KPMG-VIRTUAL INTERNSHIP PROJECT

# %% [markdown]
# ### Task:1-Data Quality Assessment

# %% [markdown]
# #### Assessment of Data quality and completeness in preparation for analysis.
# ##### The client provided KPMG with 3 dataset:
#     1.Customer Demographic
#     2.Customer Addresses
#     3.Transaction data in the past 3 months

# %%
# importing the required libraries
import pandas as pd

# %%
# reading the data
data=pd.ExcelFile("KPMG_VI_New_raw_data_update_final (1).xlsx")

# %%
# reading each file seperately
Transactions=pd.read_excel(data,'Transactions')
NewCustomerList=pd.read_excel(data,'NewCustomerList')
CustomerDemographic=pd.read_excel(data,'CustomerDemographic')
CustomerAddress=pd.read_excel(data,'CustomerAddress')

# %%
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
Transaction.shape
# Out:
# (20000, 13)

# %%
#checking for null values
Transactions.isnull().sum()
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
#checking for duplicated values
Transactions.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicated values, so the data is unique

# %%
#check for uniqueness for all column
Transactions.nunique()
# Out:
# transaction_id             20000
# product_id                   101
# customer_id                 3494
# transaction_date             364
# online_order                   2
# order_status                   2
# brand                          6
# product_line                   4
# product_class                  3
# product_size                   3
# list_price                   296
# standard_cost                103
# product_first_sold_date      100
# dtype: int64

# %%
Transactions_catcols=Transactions.select_dtypes(include='O')

# %%
# Exploring the columns:
for i in Transactions_catcols.columns:
    print('Columns Name',':',end=" ")
    print(Transactions_catcols[i].value_counts())
    print('-------------------------------')
# Out:
# Columns Name : order_status
# Approved     19821
# Cancelled      179
# Name: count, dtype: int64
# -------------------------------
# Columns Name : brand
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: count, dtype: int64
# -------------------------------
# Columns Name : product_line
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: count, dtype: int64
# -------------------------------
# Columns Name : product_class
# medium    13826
# high       3013
# low        2964
# Name: count, dtype: int64
# -------------------------------
# Columns Name : product_size
# medium    12990
# large      3976
# small      2837
# Name: count, dtype: int64
# -------------------------------

# %%
Transactions['product_first_sold_date']
# Out:
# 0        41245.0
# 1        41701.0
# 2        36361.0
# 3        36145.0
# 4        42226.0
#           ...
# 19995    37823.0
# 19996    35560.0
# 19997    40410.0
# 19998    38216.0
# 19999    36334.0
# Name: product_first_sold_date, Length: 20000, dtype: float64

# %%
Transactions['product_first_sold_date'].head()
# Out:
# 0    41245.0
# 1    41701.0
# 2    36361.0
# 3    36145.0
# 4    42226.0
# Name: product_first_sold_date, dtype: float64

# %%
Transactions['product_first_sold_date']=pd.to_datetime(Transactions['product_first_sold_date'],unit='s')

# %%
Transactions['product_first_sold_date'].head(20)
# Out:
# 0    1970-01-01 11:27:25
# 1    1970-01-01 11:35:01
# 2    1970-01-01 10:06:01
# 3    1970-01-01 10:02:25
# 4    1970-01-01 11:43:46
# 5    1970-01-01 10:50:31
# 6    1970-01-01 09:29:25
# 7    1970-01-01 11:05:15
# 8    1970-01-01 09:17:35
# 9    1970-01-01 10:36:56
# 10   1970-01-01 11:19:44
# 11   1970-01-01 11:42:52
# 12   1970-01-01 09:35:27
# 13   1970-01-01 09:36:26
# 14   1970-01-01 10:36:33
# 15   1970-01-01 10:31:13
# 16   1970-01-01 10:36:46
# 17   1970-01-01 09:24:48
# 18   1970-01-01 11:05:15
# 19   1970-01-01 10:22:17
# Name: product_first_sold_date, dtype: datetime64[ns]

# %% [markdown]
# The values in the product_first_date columns are not correct as it shows everything happening the same day at different times

# %% [markdown]
# ## Exploring New Customer List Data Set

# %%
NewCustomerList.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#                    DOB                   job_title job_industry_category  \
# 0           1957-07-12             General Manager         Manufacturing
# 1           1970-03-22         Structural Engineer              Property
# 2  1974-08-28 00:00:00      Senior Cost Accountant    Financial Services
# 3           1979-01-28  Account Representative III         Manufacturing
# 4           1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...  state    country  \
# ...

# %%
NewCustomerList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    object
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
# Dropping the unnamed column
NewCustomerList.drop(columns=['Unnamed: 16','Unnamed: 17','Unnamed: 18','Unnamed: 19','Unnamed: 20'],axis=1,inplace=True)

# %%
NewCustomerList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    object
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %%
#checking the shape of the dataset
NewCustomerList.shape
# Out:
# (1000, 18)

# %%
#checking for null values
NewCustomerList.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %% [markdown]
# There are missing values in 4 columns. They can be dropped or treated according to the nature of analysis

# %%
#checking for duplicated values
NewCustomerList.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no Duplicate values

# %%
NewCustomerList.nunique()
# Out:
# first_name                              940
# last_name                               961
# gender                                    3
# past_3_years_bike_related_purchases     100
# DOB                                     961
# job_title                               184
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        1
# owns_car                                  2
# tenure                                   23
# address                                1000
# postcode                                522
# state                                     3
# country                                   1
# property_valuation                       12
# Rank                                    324
# Value                                   324
# dtype: int64

# %%
#Exploring the columns
NewCustomerList.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value'],
#       dtype='object')

# %%
NewCustomerList_catcols=NewCustomerList.select_dtypes(include='O')

# %%
for i in NewCustomerList_catcols.columns:
    print('Column Name',':',end=" ")
    print(NewCustomerList_catcols[i].value_counts())
    print('---------------------------------------')
# Out:
# Column Name : first_name
# Rozamond     3
# Dorian       3
# Mandie       3
# Inglebert    2
# Ricki        2
#             ..
# Diego        1
# Lucilia      1
# Eddy         1
# Caron        1
# Sylas        1
# Name: count, Length: 940, dtype: int64
# ---------------------------------------
# Column Name : last_name
# Sissel       2
# Minshall     2
# Borsi        2
# Shoesmith    2
# Sturch       2
#             ..
# O'Moylane    1
# Axtens       1
# Moxted       1
# Conrad       1
# Duffill      1
# Name: count, Length: 961, dtype: int64
# ---------------------------------------
# Column Name : gender
# Female    513
# Male      470
# U          17
# Name: count, dtype: int64
# ---------------------------------------
# Column Name : DOB
# 1965-07-03    2
# 1978-01-15    2
# 1979-07-28    2
# 1995-08-13    2
# 1941-07-21    2
#              ..
# 1978-05-27    1
# 1945-08-08    1
# 1943-08-27    1
# 1999-10-24    1
# 1955-10-02    1
# Name: count, Length: 961, dtype: int64
# ...

# %%
NewCustomerList[NewCustomerList['gender']=="U"]
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases  DOB  \
# 59       Normy     Goodinge      U                                    5  NaN
# 226      Hatti     Carletti      U                                   35  NaN
# 324   Rozamond       Turtle      U                                   69  NaN
# 358      Tamas      Swatman      U                                   65  NaN
# 360      Tracy   Andrejevic      U                                   71  NaN
# 374     Agneta      McAmish      U                                   66  NaN
# 434      Gregg      Aimeric      U                                   52  NaN
# 439      Johna       Bunker      U                                   93  NaN
# 574    Harlene         Nono      U                                   69  NaN
# 598   Gerianne       Kaysor      U                                   15  NaN
# 664     Chicky      Sinclar      U                                   43  NaN
# ...

# %% [markdown]
# There are 17 columns with unknown/unspecified gender

# %% [markdown]
# ### Exploring Customer Demographic Data Set

# %%
CustomerDemographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases                  DOB  \
# 0                                   93  1953-10-12 00:00:00
# 1                                   81  1980-12-16 00:00:00
# 2                                   61  1954-01-20 00:00:00
# 3                                   33  1961-10-03 00:00:00
# 4                                   56  1977-05-13 00:00:00
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2      Recruiting Manager              Property      Mass Customer
# ...

# %%
CustomerDemographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %% [markdown]
# There are missing values in 6 columns. They can be dropped or treated according to the nature of analysis

# %%
#checking for duplicated values
CustomerDemographic.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicated values.

# %%
#checking for uniqueness for each column
CustomerDemographic.nunique()
# Out:
# customer_id                            4000
# first_name                             3139
# last_name                              3725
# gender                                    6
# past_3_years_bike_related_purchases     100
# DOB                                    3448
# job_title                               195
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        2
# default                                  90
# owns_car                                  2
# tenure                                   22
# dtype: int64

# %%
#Exploring the columns
CustomerDemographic.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
CustomerDemographic_catcols=CustomerDemographic.select_dtypes(include='O')

# %%
for i in CustomerDemographic_catcols.columns:
    print('Column Name',":",end=" ")
    print(CustomerDemographic_catcols[i].value_counts())
    print('---------------------------------------')
# Out:
# Column Name : first_name
# Max         5
# Tobe        5
# Timmie      5
# Kippy       4
# Pail        4
#            ..
# Katy        1
# Hakim       1
# Fanchon     1
# Jeanette    1
# Sarene      1
# Name: count, Length: 3139, dtype: int64
# ---------------------------------------
# Column Name : last_name
# Pristnor     3
# Ramsdell     3
# Eager        2
# Zisneros     2
# Dredge       2
#             ..
# Whittock     1
# Carwithen    1
# Blas         1
# Dearlove     1
# Oldland      1
# Name: count, Length: 3725, dtype: int64
# ---------------------------------------
# Column Name : gender
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: count, dtype: int64
# ---------------------------------------
# Column Name : DOB
# 1978-01-30    7
# 1964-07-08    4
# 1962-12-17    4
# 1978-08-19    4
# 1977-05-13    4
#              ..
# 1989-06-16    1
# 1998-09-30    1
# 1985-03-11    1
# 1989-10-23    1
# 1991-11-05    1
# ...

# %% [markdown]
# Certain categories in gender column is not correctly titled.The names in these categories are re-named

# %%
CustomerDemographic['gender']=CustomerDemographic['gender'].replace({'F':'Female','Femal':'Female','M':'Male'})

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# gender
# Female    2039
# Male      1873
# U           88
# Name: count, dtype: int64

# %%
CustomerDemographic['default'].value_counts()
# Out:
# default
# 100                                       113
# 1                                         112
# -1                                        111
# -100                                       99
# Ù¡Ù¢Ù£                                     53
#                                          ...
# testâ testâ«                               31
# /dev/null; touch /tmp/blns.fail ; echo     30
# âªâªtestâª                                 29
# ì¸ëë°í ë¥´                                 27
# ,ãã»:*:ã»ãâ( â» Ï â» )ãã»:*:ã»ãâ           25
# Name: count, Length: 90, dtype: int64

# %%
CustomerDemographic.drop('default',axis=1,inplace=True)

# %% [markdown]
# The Value are inconsistent, hence dropping the column

# %%
CustomerDemographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases                  DOB  \
# 0                                   93  1953-10-12 00:00:00
# 1                                   81  1980-12-16 00:00:00
# 2                                   61  1954-01-20 00:00:00
# 3                                   33  1961-10-03 00:00:00
# 4                                   56  1977-05-13 00:00:00
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2      Recruiting Manager              Property      Mass Customer
# ...

# %% [markdown]
# ### Exploring Customer Address DataSet

# %%
CustomerAddress.head()
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
CustomerAddress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
#checking for null values.
CustomerAddress.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %% [markdown]
# There is no null values.

# %%
#checking for duplicate values.
CustomerAddress.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicated values

# %%
#check for uniqueness for each column
CustomerAddress.nunique()
# Out:
# customer_id           3999
# address               3996
# postcode               873
# state                    5
# country                  1
# property_valuation      12
# dtype: int64

# %%
#Exploring the columns
for i in CustomerAddress.columns:
    print('Column Name',":",end=" ")
    print(CustomerAddress[i].value_counts())
    print('-----------------------------------')
# Out:
# Column Name : customer_id
# 1       1
# 2676    1
# 2663    1
# 2664    1
# 2665    1
#        ..
# 1343    1
# 1344    1
# 1345    1
# 1346    1
# 4003    1
# Name: count, Length: 3999, dtype: int64
# -----------------------------------
# Column Name : address
# 3 Mariners Cove Terrace      2
# 3 Talisman Place             2
# 64 Macpherson Junction       2
# 359 Briar Crest Road         1
# 4543 Service Terrace         1
#                             ..
# 5063 Shopko Pass             1
# 09 Hagan Pass                1
# 87897 Lighthouse Bay Pass    1
# 294 Lawn Junction            1
# 320 Acker Drive              1
# Name: count, Length: 3996, dtype: int64
# -----------------------------------
# Column Name : postcode
# 2170    31
# 2155    30
# 2145    30
# 2153    29
# 3977    26
#         ..
# 3808     1
# 3114     1
# 4721     1
# 4799     1
# 3089     1
# Name: count, Length: 873, dtype: int64
# -----------------------------------
# Column Name : state
# ...

# %%
CustomerAddress['state']=CustomerAddress['state'].replace({'New South Wales':'NSW','Victoria':'Vic'})

# %%
CustomerAddress['state'].value_counts()
# Out:
# state
# NSW    2140
# VIC     939
# QLD     838
# Vic      82
# Name: count, dtype: int64

# %% [markdown]
# #### All the columns appears to have consistent and correct information
